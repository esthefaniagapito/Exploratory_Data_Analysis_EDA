# %% [markdown]
# ### Netflix Exploratory Data Analisys - EDA

# %% [markdown]
# #### Summary
#
# 1. Data Description
#     - 1.1 Introduction
#     - 1.2 Data source and dataset
# 2. Packages load and data
# 3. Data Profilling
#     - 3.1 Understanding the dataset
#     - 3.2 Preprocessing
#     - 3.3 Preprofiling
# 4. EDA Questions
#     - 4.1 What different types of show or movie are upload on Netflix?
#     - 4.2 What is the correlation between the features?
#     - 4.3 Most watched shows on the Netflix?
#     - 4.4 Distribution of ratings?
#     - 4.5 Wich has the highest rating TV show or Movies?
#     - 4.6 Finding the best month to releasing content.
#     - 4.7 The highest watched geners on Netflix.
#     - 4.8 Released movie over the years.
#     - 4.9 Movies made on years basis.
#     - 4.10 What is the "show_id" and director of "House of cards"?
#     - 4.11 Show all the movies that were released in year 2000.
#     - 4.12 Show only the title of all TV shows that were released in India  only.
#     - 4.13 Show top 10 director, who gave the highest number of TV shows & Movies to Netflix.
#     - 4.14 In how many movies/ tv shows, 'tom Cruise' was cast?
#     - 4.15 How many movies got the "TV-14" rating in the caneda?
# 5. Conclusions

# %% [markdown]
# #### 1. Data Description
# This Netflix Dataset has information about the TV shows and Movies available on Netflix from the year 2008 to 2021. Netflix is an application that keeps growing exponentially whole around the world and it is the most famous streaming platform. This dataset also available on kaggle website for free.
#
# - **show_id**: Gives the information about show id.
# - **type**: Gives information about 2 different unique values one is TV Show and another is Movie.
# - **title**: Gives information about the title of Movie or TV Show.
# - director: Gives information about the director who directed the Movie or TV Show.
# - **cast**: Gives information about the cast who plays role in Movie or TV Show.
# - **country**: Gives information about the Name of country.
# - **date_added**: Gives information about the tv shows or movie released.
# - **release_year**: Gives information about the year when Movie or TV Show was released.
# - **rating**: Gives information about the Movie or TV Show are in which category (eg like the movies are only for students, or adults, etc).
# - **duration**: Gives information about the duration of Movie or TV Show.
# - **listed_in**: Gives information about the genre of Movie or TV Show.
# - **description**: Gives information about the description of Movie or TV Show.

# %% [markdown]
# #### 1.1 Introduction
# In This Exploratory Data Analysis is to practice Python skills learned till now on a structured data set including loading, inspecting, wrangling, exploring, and drawing conclusions from the Netflix dataset.The notebook has observations with each step in order to explain thoroughly how to approach the data set. Based on the observation some questions also are answered in the notebook for the reference though not all of them are explored in the analysis.
#
# #### 1.2 Data source and dataset
# This Netflix Dataset has information about the TV shows and Movies available on Netflix from 2018 to 2021. This dataset collected from kaggle website for free.
#
# [Download](http://)

# %% [markdown]
# #### 2. Packages load and dataset

# %% [markdown]
# Importing libraries or modules

# %%
# %%time
import numpy as np
import pandas as pd
import os
from pathlib import Path
import seaborn as sns
import ydata_profiling as prf
from matplotlib import pyplot as plt
sns.set()
# %matplotlib inline
# Out:
# CPU times: total: 2.66 s
# Wall time: 3.47 s

# %% [markdown]
# Load the dataset

# %%
p = Path(os.getcwd())
p
# Out:
# WindowsPath('C:/Users/admin/Documents/Exploratory_Data_Analysis_EDA/EDA_Classes')

# %%
netflix_dataset = str(p.parent.parent) + "\\Exploratory_Data_Analysis_EDA\Datasets\\"
df_netflix = pd.read_csv(netflix_dataset + "netflix_titles_2021.csv")

# %% [markdown]
# #### 3. Data profiling (EDA)
# #### 3.1 Understanding the dataset (basic information)

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df_netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# The dataset contains 8807 rows and 12 columns

# %%
df_netflix.size
# Out:
# 105684

# %% [markdown]
# The dataset has 105.684 elements

# %%
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_netflix.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
df_netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# #### 3.2 Preprocessing (Data cleaning)
# - Checking missing values
# - Fill null values

# %%
df_netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
miss_values = df_netflix.isnull().sum()
miss_values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Shows the total of null values for each column.

# %%
miss_values_perc = (df_netflix.isnull().sum()/df_netflix.shape[0]) * 100
miss_values_perc
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
miss_values_table = pd.concat([miss_values, miss_values_perc], axis=1, keys=['Total', '%'])
miss_values_table
# Out:
#               Total          %
# show_id           0   0.000000
# type              0   0.000000
# title             0   0.000000
# director       2634  29.908028
# cast            825   9.367549
# country         831   9.435676
# date_added       10   0.113546
# release_year      0   0.000000
# rating            4   0.045418
# duration          3   0.034064
# listed_in         0   0.000000
# description       0   0.000000

# %% [markdown]
# Creating a table to compare the total of missing values and its percentage in the dataset

# %%
sns.heatmap(df_netflix.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above output we can see that director, cast ,country columns contains maximum null values. We will see how to deal with them.
#
# So, we might delete director and cast columns because they are not going to use those features right now.

# %%
df_netflix_copy = df_netflix.copy()
df_netflix_copy.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df_netflix_copy = df_netflix_copy.dropna(how='any', subset=['director', 'cast'])
df_netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...     NaN
#
#            date_added  release_year rating  duration  \
# 2  September 24, 2021          2021  TV-MA  1 Season
# 5  September 24, 2021          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 2  To protect his family from a powerful drug lor...
# 5  The arrival of a charismatic young priest brin...

# %%
df_netflix_copy[['country', 'rating']] = df_netflix_copy[['country','rating']].fillna(value='missing')

# %%
df_netflix_copy.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# ...

# %%
df_netflix_copy.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# Continuous the process with the next steps:
# - Dealing with duplicate rows
# - Find number of duplicate rows in the dataset.
# - Print the duplicate entries and analyze.
# - Drop the duplicate entries from the dataset.

# %%
df_netflix_copy[df_netflix_copy.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df_netflix_copy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is not duplicate rows in the dataset.

# %% [markdown]
# #### 3.3 Preprofiling

# %%
netflix_profile = prf.ProfileReport(df_netflix_copy)
netflix_profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.0.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-03-02 21:40:02.893197&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# Saving file of preprofiling process

# %%
netflix_profile.to_file(output_file='netflix2021_preprofiling.html')

# %% [markdown]
# #### 4. EDA Questions

# %% [markdown]
# **4.1. What different types of show or movie are uploaded on Netflix? or
# How many TV shows & Movies are in the dataset? Show with Bar Gragh?**

# %%
df_netflix_copy['type'].value_counts()
# Out:
# Movie      5522
# TV Show     178
# Name: type, dtype: int64

# %%
sns.countplot(df_netflix_copy['type'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# **4.2 What is the Correlation between the features?**

# %%
df_netflix_copy.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# Converting the attribute "date_added" from object to date time

# %%
df_netflix_copy['date_added'] = pd.to_datetime(df_netflix_copy['date_added'])

# %%
df_netflix_copy['year_added'] = df_netflix_copy['date_added'].dt.year
df_netflix_copy['month_added'] = df_netflix_copy['date_added'].dt.month

# %%
df_netflix_copy.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# year_added               int64
# month_added              int64
# dtype: object

# %%
df_netflix_copy.corr()
# Out:
#               release_year  year_added  month_added
# release_year      1.000000    0.032265    -0.062903
# year_added        0.032265    1.000000    -0.170078
# month_added      -0.062903   -0.170078     1.000000

# %%
plt.subplots(figsize=(5,5))
sns.heatmap(df_netflix_copy.corr(), annot=True)
plt.show()

# %% [markdown]
# **4.3 Most watched shows on the Netflix.**
#
# We pretend to found the most watched show for each type (Tv show and Movie),
# but unfortunataly there is not in this dataset the time that people spend watching it.

# %% [markdown]
# **4.4 Distribution of Ratings? & What are the different rating defined by Netflix?**

# %%
sns.countplot(y=df_netflix_copy['rating'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='rating'>

# %%
df_netflix_copy['rating'].nunique()
# Out:
# 18

# %% [markdown]
# Observation:
# - The audience prefers mostly TV-MA and TV-14

# %% [markdown]
# **4.5 Which has the highest rating Tv show or Movies?**

# %%
df_netflix_copy.groupby('type')['rating'].agg(pd.Series.mode)
# Out:
# type
# Movie      TV-MA
# TV Show    TV-MA
# Name: rating, dtype: object

# %% [markdown]
# **4.6 Finding the best Month for releasing content?**

# %%
df_netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added
# 2  To protect his family from a powerful drug lor...        2021            9
# 5  The arrival of a charismatic young priest brin...        2021            9

# %%
df_netflix_copy['month_final'] = df_netflix_copy['month_added'].replace({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'})
df_netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added  \
# 2  To protect his family from a powerful drug lor...        2021            9
# 5  The arrival of a charismatic young priest brin...        2021            9
#
#   month_final
# 2         Sep
# 5         Sep

# %%
df_netflix_copy.month_final.value_counts().to_frame('Value_count')
# Out:
#      Value_count
# Jul          535
# Dec          511
# Oct          507
# Jan          503
# Apr          501
# Mar          497
# Aug          492
# Sep          475
# Nov          468
# Jun          457
# May          405
# Feb          349

# %%
sns.countplot(x=df_netflix_copy['month_final'])
# Out:
# <AxesSubplot:xlabel='month_final', ylabel='count'>

# %% [markdown]
# Observation:
# - July is the month with the most releases.

# %% [markdown]
# **4.7 Highest watched genres on Netflix?**

# %%
df_netflix_copy.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# ...

# %% [markdown]
# We need to separate the information inside "listed_in"

# %%
new_gender = df_netflix_copy['listed_in'].str.split(',',2)
new_gender
# Out:
# 2       [Crime TV Shows,  International TV Shows,  TV ...
# 5                  [TV Dramas,  TV Horror,  TV Mysteries]
# 6                              [Children & Family Movies]
# 7       [Dramas,  Independent Movies,  International M...
# 8                         [British TV Shows,  Reality TV]
#                               ...
# 8801          [Dramas,  International Movies,  Thrillers]
# 8802                   [Cult Movies,  Dramas,  Thrillers]
# 8804                           [Comedies,  Horror Movies]
# 8805                [Children & Family Movies,  Comedies]
# 8806    [Dramas,  International Movies,  Music & Music...
# Name: listed_in, Length: 5700, dtype: object

# %%
df_netflix_copy['Gender 1'] = new_gender.str.get(0)
df_netflix_copy['Gender 2'] = new_gender.str.get(1)
df_netflix_copy['Gender 3'] = new_gender.str.get(2)
df_netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added  \
# 2  To protect his family from a powerful drug lor...        2021            9
# 5  The arrival of a charismatic young priest brin...        2021            9
#
#   month_final        Gender 1                 Gender 2                Gender 3
# ...

# %%
df_netflix_copy['Gender 1'].describe(include=all)
# Out:
# count       5700
# unique        33
# top       Dramas
# freq        1586
# Name: Gender 1, dtype: object

# %%
df_netflix_copy['Gender 2'].describe(include=all)
# Out:
# count                      4485
# unique                       35
# top        International Movies
# freq                       1545
# Name: Gender 2, dtype: object

# %%
df_netflix_copy['Gender 3'].describe(include=all)
# Out:
# count                      2434
# unique                       29
# top        International Movies
# freq                        881
# Name: Gender 3, dtype: object

# %%
genre_type = ['genre 1', 'genre 2', 'genre 3']

value_count = [5700, 4485, 2434]
plt.pie(value_count, labels= genre_type, autopct="%2.2f%%")
plt.legend(title='Most watchedgenre on the Netflix')
plt.show()

# %% [markdown]
# #### 4.8 Released movie over the years

# %%
df_netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added  \
# 2  To protect his family from a powerful drug lor...        2021            9
# 5  The arrival of a charismatic young priest brin...        2021            9
#
#   month_final        Gender 1                 Gender 2                Gender 3
# ...

# %%
# no. of movies released by every year

df_netflix_copy.groupby(['release_year'])['release_year'].count().sort_values(ascending= False)
# Out:
# release_year
# 2018    691
# 2017    684
# 2016    584
# 2019    570
# 2020    499
#        ...
# 1944      1
# 1947      1
# 1946      1
# 1945      1
# 1942      1
# Name: release_year, Length: 72, dtype: int64

# %%
df_netflix_copy.release_year.value_counts().to_frame('Value_count')
# Out:
#       Value_count
# 2018          691
# 2017          684
# 2016          584
# 2019          570
# 2020          499
# ...           ...
# 1946            1
# 1959            1
# 1942            1
# 1947            1
# 1944            1
#
# [72 rows x 1 columns]

# %%
sns.countplot(x='release_year', data=df_netflix).set_title('Count plot for movies with passing years')
sns.set(rc={'figure.figsize':(60,20)})
plt.show()

# %% [markdown]
# #### 4.9 Movies made on year basis or in wich year highest number of the TV shows & movies were released? (show with bar graph)

# %%
df_netflix_copy.year_added.value_counts().to_frame('Value_count')
# Out:
#       Value_count
# 2019         1323
# 2020         1248
# 2018         1125
# 2021          962
# 2017          744
# 2016          206
# 2015           51
# 2014           14
# 2011           13
# 2013            7
# 2012            3
# 2009            2
# 2008            1
# 2010            1

# %%
df_netflix_copy['date_added'].dt.year.value_counts()
# Out:
# 2019    1323
# 2020    1248
# 2018    1125
# 2021     962
# 2017     744
# 2016     206
# 2015      51
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: date_added, dtype: int64

# %%
df_netflix_copy["date_added"].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 4.10 What is the show id and director for 'House of cards'?

# %%
df_netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added  \
# 2  To protect his family from a powerful drug lor...        2021            9
# 5  The arrival of a charismatic young priest brin...        2021            9
#
#   month_final        Gender 1                 Gender 2                Gender 3
# ...

# %%
df_netflix[df_netflix['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# For the 'House of Cards' the show if is 1059 and No director

# %% [markdown]
# #### 4.11 Show all the movies that released in year 2000.

# %%
df_netflix_copy[(df_netflix_copy['type'] == 'Movie') & (df_netflix_copy['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
df_netflix_copy[(df_netflix_copy['type'] == 'Movie') & (df_netflix_copy['release_year']==2000)].shape
# Out:
# (33, 18)

# %% [markdown]
# There are 33 movies released in year 2000.

# %% [markdown]
# #### 4.12 Show only the title of all TV shows that were released in India only

# %%
df_netflix_copy[(df_netflix_copy['country'] == 'India') & (df_netflix_copy['type'] == 'TV Show')]
# Out:
#      show_id     type                                  title  \
# 297     s298  TV Show                               Navarasa
# 1293   s1294  TV Show                          Pitta Kathalu
# 1520   s1521  TV Show                        Paava Kadhaigal
# 3036   s3037  TV Show           Jamtara - Sabka Number Ayega
# 4685   s4686  TV Show                                  GHOUL
# 6024   s6025  TV Show                              7 (Seven)
# 8172   s8173  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                director  \
# 297   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 1293  Tharun Bhascker Dhaassyam, B. V. Nandini Reddy...
# 1520  Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 3036                                    Soumendra Padhi
# 4685                                     Patrick Graham
# 6024                                        Nizar Shafi
# 8172                                      Dheeraj Berry
#
# ...

# %%
df_netflix_copy[(df_netflix_copy['country'] == 'India') & (df_netflix_copy['type'] == 'TV Show')].shape
# Out:
# (7, 18)

# %% [markdown]
# #### 4.13 Show top 10 director, who gave the highest number of TV shows & Movies to Netflix?

# %%
df_netflix_copy['director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Rajiv Chilaka             17
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Suhas Kadav               13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
df_netflix_copy["director"].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 4.14 In how many movies/tv shows, 'Tom Cruise' was cast?

# %%
df_netflix_copy[df_netflix_copy['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                   listed_in  \
# 341  2021-08-01          1999      R  189 min  Dramas, Independent Movies
# 1254 2021-03-01          1988      R  134 min      Classic Movies, Dramas
#
#                                             description  year_added  \
# 341   Through chance, history and divine interventio...        2021
# 1254  Motivated by money, a selfish workaholic seeki...        2021
#
#       month_added month_final        Gender 1             Gender 2 Gender 3
# 341             8         Aug          Dramas   Independent Movies      NaN
# ...

# %% [markdown]
# Only two movies: Magnonolia and Rain Main

# %% [markdown]
# #### How many movies got the "TV-14" rating in the Canada?

# %%
df_netflix_copy[(df_netflix_copy['type'] == 'Movie') & (df_netflix_copy['rating'] == 'TV-14') & (df_netflix_copy['country']== 'Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# 157                       Danishka Esterhazy
# 2769                  Ellen Page, Ian Daniel
# 3424                     Jean-François Blais
# 5973                         Michael Kennedy
# ...

# %%
df_netflix_copy[(df_netflix_copy['type'] == 'Movie') & (df_netflix_copy['rating'] == 'TV-14') & (df_netflix_copy['country']== 'Canada')].shape
# Out:
# (10, 18)

# %% [markdown]
# #### Post profilling

# %%
netflix_cleaned = prf.ProfileReport(df_netflix_copy)
netflix_cleaned.to_file(output_file='netfliz21_post_preprocessing.html')

# %%
netflix_cleaned.to_file(output_file='netflix21_post_processing.html')

# %% [markdown]
# ### 5. Conclusions:
#
# We explore the Netflix dataset and saw how to clean the data and then jump into how to visualize the data with Exploratory Data Analysis. We saw some basic and advanced level charts of seaborn and matplotlib like Heatmap,Pie-chart, Bar chart, Countplot.And also visualize a data with Pandas_Profiling :Preprofiling & Post_profiling.
